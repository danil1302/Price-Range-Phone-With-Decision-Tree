# %% [markdown]
# ## Import Library

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
data = pd.read_excel('Price Range Phone Dataset.xlsx')
data
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
data.shape
# Out:
# (2000, 21)

# %% [markdown]
# # Step EDA

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Kolerasi Dengan Menggunakan Heatmap

# %%
import seaborn as sns

korelasi = data.corr()
features = korelasi.index
plt.figure(figsize=(10,8))

sns.heatmap(korelasi)
plt.title("Korelasi")
# Out:
# Text(0.5, 1.0, 'Korelasi')

# %% [markdown]
# ## Tampilkan Korelasi di Tabel

# %%
data.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %% [markdown]
# ## Statistika Dasar

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
data.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
print('Banyak baris nilai nol untuk battery power :{0}'.format(len(data.loc[data['battery_power']==0])))
print('Banyak baris nilai nol untuk blue :{0}'.format(len(data.loc[data['blue']==0])))
print('Banyak baris nilai nol untuk clock speed :{0}'.format(len(data.loc[data['clock_speed']==0])))
print('Banyak baris nilai nol untuk dual sim :{0}'.format(len(data.loc[data['dual_sim']==0])))
print('Banyak baris nilai nol untuk fc :{0}'.format(len(data.loc[data['fc']==0])))
print('Banyak baris nilai nol untuk four g :{0}'.format(len(data.loc[data['four_g']==0])))
print('Banyak baris nilai nol untuk int_memory :{0}'.format(len(data.loc[data['int_memory']==0])))
print('Banyak baris nilai nol untuk m dep :{0}'.format(len(data.loc[data['m_dep']==0])))
print('Banyak baris nilai nol untuk mobile wt :{0}'.format(len(data.loc[data['mobile_wt']==0])))
print('Banyak baris nilai nol untuk n cores :{0}'.format(len(data.loc[data['n_cores']==0])))
print('Banyak baris nilai nol untuk pc :{0}'.format(len(data.loc[data['pc']==0])))
print('Banyak baris nilai nol untuk px height :{0}'.format(len(data.loc[data['px_height']==0])))
print('Banyak baris nilai nol untuk px width:{0}'.format(len(data.loc[data['px_width']==0])))
print('Banyak baris nilai nol untuk ram :{0}'.format(len(data.loc[data['ram']==0])))
print('Banyak baris nilai nol untuk sc h :{0}'.format(len(data.loc[data['sc_h']==0])))
print('Banyak baris nilai nol untuk sc w :{0}'.format(len(data.loc[data['sc_w']==0])))
print('Banyak baris nilai nol untuk talk time  :{0}'.format(len(data.loc[data['talk_time']==0])))
print('Banyak baris nilai nol untuk three g :{0}'.format(len(data.loc[data['three_g']==0])))
print('Banyak baris nilai nol untuk touch screen :{0}'.format(len(data.loc[data['touch_screen']==0])))
print('Banyak baris nilai nol untuk wifi :{0}'.format(len(data.loc[data['wifi']==0])))
print('Banyak baris nilai nol untuk price range :{0}'.format(len(data.loc[data['price_range']==0])))
# Out:
# Banyak baris nilai nol untuk battery power :0
# Banyak baris nilai nol untuk blue :1010
# Banyak baris nilai nol untuk clock speed :0
# Banyak baris nilai nol untuk dual sim :981
# Banyak baris nilai nol untuk fc :474
# Banyak baris nilai nol untuk four g :957
# Banyak baris nilai nol untuk int_memory :0
# Banyak baris nilai nol untuk m dep :0
# Banyak baris nilai nol untuk mobile wt :0
# Banyak baris nilai nol untuk n cores :0
# Banyak baris nilai nol untuk pc :101
# Banyak baris nilai nol untuk px height :2
# Banyak baris nilai nol untuk px width:0
# Banyak baris nilai nol untuk ram :0
# Banyak baris nilai nol untuk sc h :0
# Banyak baris nilai nol untuk sc w :180
# Banyak baris nilai nol untuk talk time  :0
# Banyak baris nilai nol untuk three g :477
# Banyak baris nilai nol untuk touch screen :994
# Banyak baris nilai nol untuk wifi :986
# Banyak baris nilai nol untuk price range :500

# %%
col_names = ['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi', 'price_range']

for col in col_names:
    print(data[col].value_counts())
# Out:
# battery_power
# 1872    6
# 618     6
# 1589    6
# 1715    5
# 1807    5
#        ..
# 660     1
# 1452    1
# 1005    1
# 1372    1
# 858     1
# Name: count, Length: 1094, dtype: int64
# blue
# 0    1010
# 1     990
# Name: count, dtype: int64
# clock_speed
# 0.5    413
# 2.8     85
# 2.3     78
# 2.1     76
# 1.6     76
# 2.5     74
# 0.6     74
# 1.4     70
# 1.3     68
# 1.5     67
# 2.0     67
# 1.9     65
# 0.7     64
# 2.9     62
# 1.8     62
# 1.0     61
# 1.7     60
# 2.2     59
# 0.9     58
# 2.4     58
# 0.8     58
# 1.2     56
# 2.6     55
# 2.7     55
# 1.1     51
# 3.0     28
# Name: count, dtype: int64
# dual_sim
# 1    1019
# 0     981
# Name: count, dtype: int64
# fc
# 0     474
# 1     245
# 2     189
# 3     170
# 5     139
# 4     133
# 6     112
# 7     100
# 9      78
# 8      77
# 10     62
# 11     51
# 12     45
# 13     40
# 16     24
# 15     23
# 14     20
# 18     11
# 17      6
# 19      1
# Name: count, dtype: int64
# four_g
# 1    1043
# 0     957
# ...

# %% [markdown]
# ## Apply Model

# %%
X = data.drop(['price_range'], axis=1)

y = data['price_range']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.20, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((1600, 20), (400, 20))

# %%
X_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 968            1923     0          0.5         1   7       0          46
# 240             633     1          2.2         0   0       1          49
# 819            1236     0          0.9         1   2       1          57
# 692             781     0          1.1         0   2       0          38
# 420            1456     1          0.5         1   7       0           7
# ...             ...   ...          ...       ...  ..     ...         ...
# 1130           1975     1          1.9         1   2       0          31
# 1294            589     1          0.5         0   1       1          59
# 860            1829     1          0.5         0   0       1          15
# 1459           1927     0          0.9         1   3       0          11
# 1126            635     1          0.6         1   1       1          50
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
X_test
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1860           1646     0          2.5         0   3       1          25
# 353            1182     0          0.5         0   7       1           8
# 1333           1972     0          2.9         0   9       0          14
# 905             989     1          2.0         0   4       0          17
# 1289            615     1          0.5         1   7       0          58
# ...             ...   ...          ...       ...  ..     ...         ...
# 965            1379     0          0.5         1   1       0          19
# 1284            991     0          2.0         0   2       1          12
# 1739           1044     0          1.8         0   4       1          12
# 261             728     0          2.7         1   0       0          25
# 535            1185     0          1.9         0   0       0          31
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y_train.shape, y_test.shape
# Out:
# ((1600,), (400,))

# %%
y_train
# Out:
# 968     1
# 240     2
# 819     0
# 692     3
# 420     1
#        ..
# 1130    3
# 1294    0
# 860     2
# 1459    3
# 1126    1
# Name: price_range, Length: 1600, dtype: int64

# %%
y_test
# Out:
# 1860    0
# 353     2
# 1333    1
# 905     3
# 1289    1
#        ..
# 965     3
# 1284    2
# 1739    1
# 261     1
# 535     2
# Name: price_range, Length: 400, dtype: int64

# %% [markdown]
# ## Training

# %% [markdown]
# ### Classification

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
klf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)

klf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
y_pred_gini = klf_gini.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Skor akurasi model dengan kriteria index gini: {0:0.4f}'. format(accuracy_score(y_test,y_pred_gini)))
# Out:
# Skor akurasi model dengan kriteria index gini: 0.7400

# %%
y_pred_train_gini = klf_gini.predict(X_train)

y_pred_train_gini
# Out:
# array([1, 2, 1, ..., 1, 2, 1], dtype=int64)

# %%
print('Training-set akurasi skor : {0:0.4f}'.format(accuracy_score(y_train, y_pred_train_gini)))
# Out:
# Training-set akurasi skor : 0.7806

# %% [markdown]
# ## Check Overfitting dan Underfitting

# %%
print('Training set skor: {:.4f}'.format(klf_gini.score(X_train, y_train)))

print('Test set skor: {:.4f}'.format(klf_gini.score(X_test, y_test)))
# Out:
# Training set skor: 0.7806
# Test set skor: 0.7400

# %% [markdown]
# ## Visualisasi Decision Tree

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(klf_gini.fit(X_train, y_train))
# Out:
# [Text(0.5, 0.875, 'x[13] <= 2217.5\ngini = 0.75\nsamples = 1600\nvalue = [395, 409, 408, 388]'),
#  Text(0.25, 0.625, 'x[13] <= 1052.5\ngini = 0.587\nsamples = 840\nvalue = [395, 357, 88, 0]'),
#  Text(0.125, 0.375, 'x[11] <= 1445.0\ngini = 0.164\nsamples = 334\nvalue = [304, 30, 0, 0]'),
#  Text(0.0625, 0.125, 'gini = 0.112\nsamples = 320\nvalue = [301, 19, 0, 0]'),
#  Text(0.1875, 0.125, 'gini = 0.337\nsamples = 14\nvalue = [3, 11, 0, 0]'),
#  Text(0.375, 0.375, 'x[0] <= 1007.5\ngini = 0.52\nsamples = 506\nvalue = [91, 327, 88, 0]'),
#  Text(0.3125, 0.125, 'gini = 0.514\nsamples = 174\nvalue = [74, 96, 4, 0]'),
#  Text(0.4375, 0.125, 'gini = 0.449\nsamples = 332\nvalue = [17, 231, 84, 0]'),
#  Text(0.75, 0.625, 'x[13] <= 3013.5\ngini = 0.557\nsamples = 760\nvalue = [0, 52, 320, 388]'),
#  Text(0.625, 0.375, 'x[0] <= 573.5\ngini = 0.447\nsamples = 348\nvalue = [0, 52, 249, 47]'),
#  Text(0.5625, 0.125, 'gini = 0.466\nsamples = 27\nvalue = [0, 17, 10, 0]'),
# ...

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,15))
plot_tree(klf_gini, max_depth = 1,  
            rounded = True,
            filled = True, 
            impurity = True, 
            node_ids = True,
          )
plt.show()

# %% [markdown]
# ## Classifier with criterion entropy

# %%
klf_en = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)


klf_en.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %%
y_pred_en = klf_en.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Skor model akurasi dengan criterion entropy: {0:0.4f}'. format(accuracy_score(y_test, y_pred_en)))
# Out:
# Skor model akurasi dengan criterion entropy: 0.7550

# %%
y_pred_train_en = klf_en.predict(X_train)

y_pred_train_en
# Out:
# array([1, 3, 1, ..., 1, 2, 1], dtype=int64)

# %%
print('Training-set akurasi skor: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_en)))
# Out:
# Training-set akurasi skor: 0.7681

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

con_mat = confusion_matrix(y_test, y_pred_en)

print('Confusion matrix\n\n', con_mat)
# Out:
# Confusion matrix
#
#  [[79 26  0  0]
#  [ 4 73 14  0]
#  [ 0 16 59 17]
#  [ 0  0 21 91]]

# %% [markdown]
# ## Confusion Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_en))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84       105
#            1       0.63      0.80      0.71        91
#            2       0.63      0.64      0.63        92
#            3       0.84      0.81      0.83       112
#
#     accuracy                           0.76       400
#    macro avg       0.76      0.75      0.75       400
# weighted avg       0.77      0.76      0.76       400

# %% [markdown]
# ## Model Deploymment

# %%
import pickle
pickle.dump(klf_gini, open('DecisionTree.pkl', 'wb'))
